# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %% [markdown]
# ### Import the necessary libraries

# %%
# IMPORT LIBRARIES AND PACKAGES
import tensorflow as tf
import csv
import numpy as np
import pandas as pd
from PIL import Image

from keras import Model
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.layers import Conv2D, Reshape
from keras.utils import Sequence
from keras.backend import epsilon

# %% [markdown]
# ### Change directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/R9 Bounding Box Internal Lab/')

# %% [markdown]
# ### Load the training data from train.csv file

# %%
train_df = pd.read_csv('train_labels.csv')

# %% [markdown]
# ### Print the shape of the train dataset

# %%
train_df.shape
# Out:
# (173, 8)

# %%
train_df.head()
# Out:
#          filename  width  height    class  xmin  ymin  xmax  ymax
# 0  raccoon-17.jpg    259     194  raccoon    95    60   167   118
# 1  raccoon-11.jpg    660     432  raccoon     3     1   461   431
# 2  raccoon-63.jpg    600     400  raccoon    74   107   280   290
# 3  raccoon-63.jpg    600     400  raccoon   227    93   403   298
# 4  raccoon-60.jpg    273     185  raccoon    58    33   197   127

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
# SETTINGS

ALPHA = 1.0 
IMAGE_SIZE = 128 # MobileNet takes images of size 128*128*3 
EPOCHS = 10 
BATCH_SIZE = 32

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
import csv
with open('train_labels.csv', 'r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile), 4))
    reader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    for col, row in enumerate(reader):
      if col == 0 :
        continue
      path, image_width, image_height, _,x0, y0, x1, y1 = row
      image_width = int(image_width)
      image_height = int (image_height)
      x0 = int(x0)
      y0 = int(y0)
      x1 = int(x1)
      y1 = int(y1)
      path = "./images/" + path
      image_width = int(image_width)
      coords[col, 0] = x0 * IMAGE_SIZE / image_width # Normalize bounding box by image size
      coords[col, 1] = y0 * IMAGE_SIZE / image_height # Normalize bounding box by image size
      coords[col, 2] = (x1 - x0) * IMAGE_SIZE / image_width # Normalize bounding box by image size
      coords[col, 3] = (y1 - y0) * IMAGE_SIZE / image_height
      paths.append(path)

# %%
coords = np.delete(coords, (0), axis=0)

# %%
coords.shape
# Out:
# (173, 4)

# %%
coords[0]
# Out:
# array([46.94980695, 39.58762887, 35.58301158, 38.26804124])

# %%
paths[0]
# Out:
# './images/raccoon-17.jpg'

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, f in enumerate(paths):
    img = Image.open(f) # Read image
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE)) # Resize image
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
model = MobileNet(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, alpha=ALPHA) # Load pre-trained mobilenet
# Do not include classification (top) layer

# to freeze layers, except the new top layer, of course, which will be added below
for layer in model.layers:
    layer.trainable = False

# Add new top layer which is a conv layer of the same size as the previous layer so that only 4 coords of BBox can be output
x = model.layers[-1].output
x = Conv2D(4, kernel_size=4, name="coords")(x)
# In the line above kernel size should be 3 for img size 96, 4 for img size 128, 5 for img size 160 etc.
x = Reshape((4,))(x) # These are the 4 predicted coordinates of one BBox

model = Model(inputs=model.input, outputs=x)

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_func(loss, [y_true, y_pred], tf.float32)
    return iou

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
model.compile(optimizer='Adam', loss='mse', metrics=[IoU]) # Regression loss is MSE
# Out:
# WARNING:tensorflow:From <ipython-input-66-a811784d62ce>:25: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.

# %%
gt = coords
model.fit(batch_images,gt,
            epochs=30,batch_size = 32,
            verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 173/173 [==============================] - 8s 48ms/step - loss: 3116.0509 - IoU: 0.0711
# Epoch 2/30
# 173/173 [==============================] - 5s 32ms/step - loss: 784.5227 - IoU: 0.3803
# Epoch 3/30
# 173/173 [==============================] - 5s 32ms/step - loss: 635.5723 - IoU: 0.5346
# Epoch 4/30
# 173/173 [==============================] - 5s 31ms/step - loss: 630.8314 - IoU: 0.5249
# Epoch 5/30
# 173/173 [==============================] - 5s 31ms/step - loss: 386.1341 - IoU: 0.5814
# Epoch 6/30
# 173/173 [==============================] - 5s 31ms/step - loss: 287.0385 - IoU: 0.5858
# Epoch 7/30
# 173/173 [==============================] - 5s 31ms/step - loss: 257.9299 - IoU: 0.5981
# Epoch 8/30
# 173/173 [==============================] - 6s 32ms/step - loss: 206.4254 - IoU: 0.6420
# Epoch 9/30
# 173/173 [==============================] - 5s 31ms/step - loss: 173.2310 - IoU: 0.6956
# Epoch 10/30
# 173/173 [==============================] - 6s 32ms/step - loss: 151.6320 - IoU: 0.7197
# Epoch 11/30
# 173/173 [==============================] - 5s 32ms/step - loss: 136.1857 - IoU: 0.7224
# Epoch 12/30
# 173/173 [==============================] - 6s 32ms/step - loss: 126.4719 - IoU: 0.7295
# Epoch 13/30
# 173/173 [==============================] - 6s 32ms/step - loss: 121.3639 - IoU: 0.7434
# Epoch 14/30
# 173/173 [==============================] - 6s 32ms/step - loss: 99.8932 - IoU: 0.7537
# Epoch 15/30
# 173/173 [==============================] - 5s 32ms/step - loss: 99.7018 - IoU: 0.7728
# Epoch 16/30
# 173/173 [==============================] - 5s 32ms/step - loss: 94.2313 - IoU: 0.7690
# Epoch 17/30
# 173/173 [==============================] - 5s 31ms/step - loss: 84.4427 - IoU: 0.7848
# Epoch 18/30
# 173/173 [==============================] - 5s 32ms/step - loss: 75.3501 - IoU: 0.7980
# Epoch 19/30
# 173/173 [==============================] - 5s 32ms/step - loss: 77.7350 - IoU: 0.7879
# Epoch 20/30
# 173/173 [==============================] - 5s 32ms/step - loss: 80.0667 - IoU: 0.7930
# Epoch 21/30
# 173/173 [==============================] - 5s 32ms/step - loss: 69.9841 - IoU: 0.8106
# Epoch 22/30
# 173/173 [==============================] - 6s 32ms/step - loss: 68.1811 - IoU: 0.8093
# Epoch 23/30
# 173/173 [==============================] - 5s 32ms/step - loss: 67.0142 - IoU: 0.8195
# Epoch 24/30
# 173/173 [==============================] - 6s 32ms/step - loss: 65.8452 - IoU: 0.8164
# Epoch 25/30
# 173/173 [==============================] - 6s 32ms/step - loss: 66.6884 - IoU: 0.8242
# Epoch 26/30
# 173/173 [==============================] - 5s 31ms/step - loss: 59.7412 - IoU: 0.8259
# Epoch 27/30
# 173/173 [==============================] - 5s 31ms/step - loss: 63.5968 - IoU: 0.8224
# Epoch 28/30
# 173/173 [==============================] - 5s 31ms/step - loss: 61.3175 - IoU: 0.8272
# Epoch 29/30
# 173/173 [==============================] - 5s 31ms/step - loss: 60.0262 - IoU: 0.8239
# Epoch 30/30
# 173/173 [==============================] - 6s 32ms/step - loss: 60.6882 - IoU: 0.8345

# %% [markdown]
# ### Pick a test image from the given data

# %%
import cv2
filename = './raccoon-test2.jpg'
unscaled = cv2.imread(filename) # Original image for display

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
image_height, image_width, _ = unscaled.shape
image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE)) # Rescaled image to run the network
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = model.predict(x=np.array([feat_scaled]))[0] # Predict the BBox

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * image_width / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * image_height / IMAGE_SIZE)

x1 = int((region[2]) * image_width / IMAGE_SIZE)
y1 = int((region[3]) * image_height / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0) , (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %% [markdown]
# # Time Series Prediction using LSTM

# %% [markdown]
# ### Download Data
# Link: https://datamarket.com/data/set/2324/daily-minimum-temperatures-in-melbourne-australia-1981-1990#!ds=2324&display=line
#
# #### Description
# Daily minimum temperatures in Melbourne, Australia, 1981-1990
#
# Units: Degrees Celcius
#
# #### Steps before loading
# - Rename the column name with temprature values to "Temprature"
# - In the last, there is one extra row in the data, remove it by opening the file and save it again.
# - There are some values in Temprature column which have a "?" before them, they will give error, remove "?" before them and save the file
# - If you don't want to do these steps, just load the data file given by Great Learning.

# %% [markdown]
# #### Mount google drive

# %%
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import GRU, Dense
from keras.layers import LSTM

# %%
## Mounting already done above

# %% [markdown]
# #### Change your present working directory

# %%
# Already Set
# import os
# os.chdir('/content/drive/My Drive/Colab Notebooks/R9 Bounding Box Internal Lab/')

# %% [markdown]
# ### Load your data file

# %%
df = pd.read_csv('daily-minimum-temperatures-in-me.csv', index_col='Date')
print(df.head())
# Out:
#             Temperature
# Date
# 1981-01-01         20.7
# 1981-01-02         17.9
# 1981-01-03         18.8
# 1981-01-04         14.6
# 1981-01-05         15.8

# %% [markdown]
# #### Plot data

# %%
df.plot()

# %% [markdown]
# #### Descibe your dataframe

# %%
df.describe()
# Out:
#        Temperature
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %% [markdown]
# #### Check for null values

# %%
print(df.isnull().any(axis=1).sum())
# Out:
# 0

# %% [markdown]
# #### Drop null values

# %%
df.dropna(inplace=True)

# %% [markdown]
# #### Get the representation of the distribution of data in the form of histogram

# %%
df.hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7c86435b38>]],
#       dtype=object)

# %% [markdown]
# #### Check the maximum and minimum values

# %%
# Scaled Data
print('Min', np.min(df))
print('Max', np.max(df))
# Out:
# Min Temperature    0.0
# dtype: float64
# Max Temperature    26.3
# dtype: float64

# %% [markdown]
# ### Normalize the data

# %%
dataset = df.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(dataset)

# %% [markdown]
# #### Check the maximum and minimum values of scaled data

# %%
print('Min', np.min(scaled))
print('Max', np.max(scaled))
# Out:
# Min 0.0
# Max 1.0

# %% [markdown]
# #### Look into some of the scaled values

# %%
print(scaled[:10])
# Out:
# [[0.7870723 ]
#  [0.68060837]
#  [0.71482889]
#  [0.55513311]
#  [0.60076048]
#  [0.60076048]
#  [0.60076048]
#  [0.66159696]
#  [0.82889733]
#  [0.7604563 ]]

# %% [markdown]
# ### Split data into Training and Testing

# %%
train_size = int(len(scaled) * 0.70)
test_size = len(scaled - train_size)
train, test = scaled[0:train_size, :], scaled[train_size: len(scaled), :]

# %% [markdown]
# #### Print train and test size

# %%
print('train: {}\ntest: {}'.format(len(train), len(test)))
# Out:
# train: 2555
# test: 1095

# %% [markdown]
# ## Create the sequential data
# Map the temprature at a particular time t to the temprature at time t+n, where n is any number you define.
#
# For example: to map tempratures of consecutive days, use t+1, i.e. loop_back = 1

# %% [markdown]
# #### Define your function to create dataset

# %%
def create_dataset(dataset, look_back=1):
    print(len(dataset), look_back)
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        #print(i)
        #print('X {} to {}'.format(i, i+look_back))
        #print(a)
        #print('Y {}'.format(i + look_back))
        #print(dataset[i + look_back, 0])
        dataset[i + look_back, 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# #### Use function to get training and test set

# %%
look_back = 3
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)
# Out:
# 2555 3
# 1095 3

# %% [markdown]
# #### Transform the prepared train and test input data into the expected structure using numpy.reshape()

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (2551, 3, 1)
# (1091, 3, 1)

# %% [markdown]
# ## Define Model

# %% [markdown]
# ### Define sequntial model, add LSTM layer and compile the model

# %%
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ### Summarize your model

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (1, 4)                    96
# _________________________________________________________________
# dense_2 (Dense)              (1, 1)                    5
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
model.fit(X_train, y_train, epochs=50, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 2551/2551 [==============================] - 11s 4ms/step - loss: 0.0159
# Epoch 2/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0114
# Epoch 3/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0106
# Epoch 4/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0104
# Epoch 5/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0101
# Epoch 6/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0101
# Epoch 7/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0101
# Epoch 8/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0100
# Epoch 9/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0099
# Epoch 10/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0098
# Epoch 11/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0098
# Epoch 12/50
# 2551/2551 [==============================] - 9s 3ms/step - loss: 0.0098
# Epoch 13/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0098
# Epoch 14/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0097
# Epoch 15/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0098
# Epoch 16/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0098
# Epoch 17/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0098
# Epoch 18/50
# 2551/2551 [==============================] - 9s 3ms/step - loss: 0.0097
# Epoch 19/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 20/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 21/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0098
# Epoch 22/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 23/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 24/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 25/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 26/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 27/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 28/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 29/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 30/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 31/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 32/50
# 2551/2551 [==============================] - 9s 3ms/step - loss: 0.0097
# Epoch 33/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 34/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0098
# Epoch 35/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 36/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0096
# Epoch 37/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 38/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 39/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 40/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 41/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 42/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 43/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0096
# Epoch 44/50
# 2551/2551 [==============================] - 7s 3ms/step - loss: 0.0096
# Epoch 45/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 46/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 47/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0097
# Epoch 48/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 49/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096
# Epoch 50/50
# 2551/2551 [==============================] - 8s 3ms/step - loss: 0.0096

# %% [markdown]
# ## Make Predictions and Evaluate your model

# %%
import math
from sklearn.metrics import mean_squared_error

trainPredict = model.predict(X_train, batch_size=batch_size)
model.reset_states()

testPredict = model.predict(X_test, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 2.56 RMSE
# Test Score: 2.40 RMSE

# %% [markdown]
# ## Plot the results

# %%
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(scaled)-1, :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(scaled))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
